# %%
import requests
import flask
from flask_googlemaps import GoogleMaps
from flask_googlemaps import Map, icons

# %%
r = requests.get("https://maps.googleapis.com/maps/api/directions/json?origin=sydney,au&destination=perth,au&waypoints=via:-37.81223%2C144.96254%7Cvia:-34.92788%2C138.60008&key=AIzaSyAQ1pkXS4Ri2EX2AxK9aOcXcW50I0HolS0")
r.json()
# Out:
# {'geocoded_waypoints': [{'geocoder_status': 'OK',
#    'place_id': 'ChIJP3Sa8ziYEmsRUKgyFmh9AQM',
#    'types': ['colloquial_area', 'locality', 'political']},
#   {'geocoder_status': 'OK',
#    'place_id': 'Ei4zNDUgTG9uc2RhbGUgU3QsIE1lbGJvdXJuZSBWSUMgMzAwMCwgQXVzdHJhbGlh',
#    'types': ['street_address']},
#   {'geocoder_status': 'OK',
#    'place_id': 'ChIJh9v7K9jOsGoRp5WYZjbHdgU',
#    'types': ['street_address']},
#   {'geocoder_status': 'OK',
#    'place_id': 'ChIJPXNH22yWMioR0FXfNbXwBAM',
#    'types': ['colloquial_area', 'locality', 'political']}],
#  'routes': [{'bounds': {'northeast': {'lat': -30.9600752, 'lng': 151.2092622},
#     'southwest': {'lat': -37.83308650000001, 'lng': 115.8604035}},
#    'copyrights': 'Map data ©2018 Google',
#    'legs': [{'distance': {'text': '4,298 km', 'value': 4298026},
#      'duration': {'text': '1 day 21 hours', 'value': 161347},
#      'end_address': 'Perth WA, Australia',
#      'end_location': {'lat': -31.9504886, 'lng': 115.8604035},
# ...
